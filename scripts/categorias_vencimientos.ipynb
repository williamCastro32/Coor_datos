# %%
import pandas as pd

# %%
import os
import pandas as pd
from pathlib import Path

# Definir la ruta de la carpeta en el escritorio
desktop = Path.home() / "Desktop"
folder = desktop / "reportes37"  # Reemplaza con el nombre de tu carpeta

# Lista para almacenar todos los dataframes
all_dataframes = []

# Iterar sobre todos los archivos xlsx en la carpeta
for file in folder.glob('*.xlsx'):
    # Leer el archivo Excel
    df = pd.read_excel(file)
    # Añadir el dataframe a la lista
    all_dataframes.append(df)

# # Combinar todos los dataframes
# combined_df = pd.concat(all_dataframes, ignore_index=True)

# # Guardar el resultado en un nuevo archivo Excel
# output_file = desktop / "Informe_Combinado.xlsx"
# combined_df.to_excel(output_file, index=False)

# print(f"Informe combinado guardado en: {output_file}")

# %%
all_dataframes[0]
# Out:
#            Cedula                   Nombres  Dias Mora agrupacion  \
# 0          416993           Mario Alejandro         27      16-30
# 1          521570  Mauricio Alfredo Alfredo         58     31-120
# 2          582095         Yelizmar Mercedes         43     31-120
# 3          629770           Dayana Coromoto        149    121-210
# 4          644622               Juan Manuel         43     31-120
# ...           ...                       ...        ...        ...
# 14967  1238344570        Mirangella Jinnett        757       >310
# 14968  1243139646           Jhoiber Armando        561       >310
# 14969  1243139989        Breintner Humberto        561       >310
# 14970  2000001098              Ricardo Jose        773       >310
# 14971  5041059641         Alexander Antonio         58     31-120
#
#        Vlr. Cuota Vencida  Intereses de Mora  Gastos de Cobranza  \
# 0                86932.97            1405.14         3749.276475
# ...

# %%
combined_df
# Out:
#         Cedula                   Nombres  Dias Mora agrupacion  \
# 0       416993           Mario Alejandro       27.0      16-30
# 1       521570  Mauricio Alfredo Alfredo       58.0     31-120
# 2       582095         Yelizmar Mercedes       43.0     31-120
# 3       629770           Dayana Coromoto      149.0    121-210
# 4       644622               Juan Manuel       43.0     31-120
# ...        ...                       ...        ...        ...
# 138898     NaN                       NaN        NaN        NaN
# 138899     NaN                       NaN        NaN        NaN
# 138900     NaN                       NaN        NaN        NaN
# 138901     NaN                       NaN        NaN        NaN
# 138902     NaN                       NaN        NaN        NaN
#
#         Vlr. Cuota Vencida  Intereses de Mora  Gastos de Cobranza  \
# 0                 86932.97            1405.14         3749.276475
# 1                538144.44           13974.33        29997.630075
# ...
