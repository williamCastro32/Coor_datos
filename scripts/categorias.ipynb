# %%
import pandas as pd

# %%
df = pd.read_excel('../datos/LISTADO_DE_ALIADOS_Y_CATEGORIAS.xlsx', sheet_name='CATEGORIAS QUERY')

# %%
df
# Out:
#                                             Franquicia  \
# 0                            CONFECCIONES CIELITO LTDA
# 1                                  CALZADO ALIATTI SAS
# 2                                  INVERSIONES GLZ SAS
# 3    ORTHOPLAN TODAVIA CON LOS DIENTES TORCIDOS CAL...
# 4    ORTHOPLAN TODAVIA CON LOS DIENTES TORCIDOS CAL...
# ..                                                 ...
# 947                         JUAN DAVID OCAMPO FLORIANO
# 948                                    MULTISHOP S.A.S
# 949                               AMPARO GARCIA OSORIO
# 950                            ROSALBA PAPAMIJA GARCIA
# 951                  HERNAN ANTONIIO TIGREROS GRAJALES
#
#                            TIENDA               CATEGORIA  \
# 0               CIELITO CARTAGENA     VESTUARIO - CALZADO
# 1     F NEBULONI PUNTO DE FABRICA     VESTUARIO - CALZADO
# 2                  GLAMAZON TULUÁ     VESTUARIO - CALZADO
# 3             002 ORTHOPLAN NORTE  ODONTOLOGIAS Y OPTICAS
# ...
